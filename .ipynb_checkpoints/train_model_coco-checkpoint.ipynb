# %% [markdown]
# # test of detectron2 on coco dataset

# %%
dataset_name = "woonboten_groningen"
basedir = "/datadrive/BGT_object_detection/WOONBOTEN_groningen/"
validation_dataset_name = "woonboten_amsterdam"
validation_basedir = "/datadrive/BGT_object_detection/WOONBOTEN_amsterdam/"

# %%
import matplotlib.pyplot as plt
import random
import os
import cv2
import torch
import detectron2.utils.comm as comm
from detectron2.utils.visualizer import Visualizer
from detectron2.data.datasets import register_coco_instances
from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.data import build_detection_train_loader
from detectron2.engine import DefaultPredictor
from detectron2.engine import DefaultTrainer
from detectron2.engine import HookBase
from detectron2.config import get_cfg

# %%
register_coco_instances(dataset_name, {}, os.path.join(basedir, "annotation.json"), os.path.join(basedir, "train/"))
metadata = MetadataCatalog.get(dataset_name)
dataset_dicts = DatasetCatalog.get(dataset_name)

register_coco_instances(validation_dataset_name, {}, os.path.join(validation_basedir, "annotation.json"), os.path.join(validation_basedir, "train/"))
validation_metadata = MetadataCatalog.get(validation_dataset_name)
validation_dataset_dicts = DatasetCatalog.get(validation_dataset_name)
# Out:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
#
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.

# %%
fig, axs = plt.subplots(1,3, figsize=(20,20))

for i, d in enumerate(random.sample(dataset_dicts, 3)):
    img = plt.imread(d["file_name"])[:,:,:3] * 255 # png storen in 0-1 range with empty alpha channel
    
    visualizer = Visualizer(img[:, :, ::-1], metadata=metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    image_with_labels = vis.get_image()[:, :, ::-1]
    
    axs[i].imshow(vis.get_image()[:, :, ::-1])

# %%
cfg = get_cfg()
cfg.merge_from_file(
    "./configs/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"
)
cfg.DATASETS.TRAIN = (dataset_name,)
cfg.DATASETS.TEST = ()  # no metrics implemented for this dataset
cfg.DATALOADER.NUM_WORKERS = 5
cfg.MODEL.WEIGHTS = "detectron2://COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl"  # initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 20
cfg.SOLVER.BASE_LR = 0.02
cfg.SOLVER.MAX_ITER = (
    100
)
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = (
    512
)  # faster, and good enough for this toy dataset
cfg.DATASETS.VAL = (validation_dataset_name,)

# %%
class ValidationLoss(HookBase):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg.clone()
        self.cfg.DATASETS.TRAIN = cfg.DATASETS.VAL
        self._loader = iter(build_detection_train_loader(self.cfg))
        
    def after_step(self):
        data = next(self._loader)
        with torch.no_grad():
            loss_dict = self.trainer.model(data)
            
            losses = sum(loss_dict.values())
            assert torch.isfinite(losses).all(), loss_dict

            loss_dict_reduced = {"val_" + k: v.item() for k, v in 
                                 comm.reduce_dict(loss_dict).items()}
            losses_reduced = sum(loss for loss in loss_dict_reduced.values())
            if comm.is_main_process():
                self.trainer.storage.put_scalars(total_val_loss=losses_reduced, 
                                                 **loss_dict_reduced)

# %%
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

trainer = DefaultTrainer(cfg) 
val_loss = ValidationLoss(cfg)  
trainer.register_hooks([val_loss])

# swap the order of PeriodicWriter and ValidationLoss
trainer._hooks = trainer._hooks[:-2] + trainer._hooks[-2:][::-1]
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [10/27 12:50:09 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
# ...

# %%
cfg.OUTPUT_DIR
# Out:
# './output'

# %%
cfg.MODEL.WEIGHTS = os.path.join("./output", "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7   # set the testing threshold for this model
cfg.DATASETS.TEST = ("woonboten_groningen", )
predictor = DefaultPredictor(cfg)

# %%
fig, axs = plt.subplots(1,3, figsize=(30,30))
for i, d in enumerate(random.sample(validation_dataset_dicts, 3)):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=validation_metadata, 
                   scale=0.8
#                    instance_mode=ColorMode.IMAGE_BW   # remove the colors of unsegmented pixels
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    axs[i].imshow(v.get_image()[:, :, ::-1])

# %%
# test inference on large set of unannotated images
import glob
import numpy as np
import cv2
from affine import Affine
import matplotlib.pyplot as plt
import pygeoj
from detectron2.utils.visualizer import Visualizer

from imantics import Polygons, Mask

basedir = "/datadrive/BGT_object_detection/WOONBOTEN_groningen/train/"
filepaths = glob.glob(basedir + "*.png")

wkt_crs = 'PROJCS["Amersfoort / RD New",GEOGCS["Amersfoort",DATUM["Amersfoort",SPHEROID["Bessel 1841",6377397.155,299.1528128,AUTHORITY["EPSG","7004"]],TOWGS84[565.417,50.3319,465.552,-0.398957,0.343988,-1.8774,4.0725],AUTHORITY["EPSG","6289"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4289"]],PROJECTION["Oblique_Stereographic"],PARAMETER["latitude_of_origin",52.15616055555555],PARAMETER["central_meridian",5.38763888888889],PARAMETER["scale_factor",0.9999079],PARAMETER["false_easting",155000],PARAMETER["false_northing",463000],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["X",EAST],AXIS["Y",NORTH],AUTHORITY["EPSG","28992"]]'

for filepath in filepaths:
    print(filepath)
    coords = os.path.basename(filepath).split(".png")[0].split("_")[:2]
    coords = [float(c) for c in coords]
    print(coords)
    x = coords[0]
    y = coords[1]
    
    # make transform
    transform = Affine.translation(float(x), (float(y) -1)) * Affine.scale(0.1, 0.1)

    im = cv2.imread(filepath)
    outputs = predictor(im)
    masks = np.array(outputs['instances'].pred_masks.cpu())
    print(masks.shape)
    polygon = Mask(masks[0]).polygons()

#     print(polygon.points)
#     print(polygon.segmentation)

    # do saving / post-processing

    
    break
# Out:
# /datadrive/BGT_object_detection/WOONBOTEN_groningen/train/234718.0615_581325.5345000001_50.png
# [234718.0615, 581325.5345000001]
# (4, 512, 512)
